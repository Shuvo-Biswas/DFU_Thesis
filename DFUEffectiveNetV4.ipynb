# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import cv2
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.metrics import BinaryAccuracy, FalsePositives, FalseNegatives, TruePositives, TrueNegatives, Precision, Recall, AUC
from tqdm import tqdm
import os
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import EfficientNetB1
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard, ModelCheckpoint
from sklearn.metrics import classification_report,confusion_matrix
import ipywidgets as widgets
import io
from PIL import Image
from IPython.display import display,clear_output
from warnings import filterwarnings

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
labels = ['Abnormal(Ulcer)','Normal(Healthy skin)']

# %%
X_train = []
y_train = []
image_size = 224
for i in labels:
    folderPath = os.path.join('/content/drive/MyDrive/DFU_dataset','train',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        try:
            img = cv2.resize(img,(image_size, image_size))
        except:
            break
        X_train.append(img)
        y_train.append(i)
        
for i in labels:
    folderPath = os.path.join('/content/drive/MyDrive/DFU_dataset','test',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size,image_size))
        X_train.append(img)
        y_train.append(i)
        
X_train = np.array(X_train)
y_train = np.array(y_train)
# Out:
# 100%|██████████| 1740/1740 [00:24<00:00, 71.36it/s]
# 100%|██████████| 1170/1170 [00:15<00:00, 76.49it/s]
# 100%|██████████| 170/170 [00:01<00:00, 90.57it/s]
# 100%|██████████| 110/110 [00:01<00:00, 97.78it/s]

# %%
X_train, y_train = shuffle(X_train,y_train, random_state=1010)

# %%
X_train,X_test,y_train,y_test = train_test_split(X_train,y_train, test_size=0.1,random_state=1010)

# %%
y_train_new = []
for i in y_train:
    y_train_new.append(labels.index(i))
y_train = y_train_new
y_train = tf.keras.utils.to_categorical(y_train)


y_test_new = []
for i in y_test:
    y_test_new.append(labels.index(i))
y_test = y_test_new
y_test = tf.keras.utils.to_categorical(y_test)

# %%
import keras
import keras.utils
from keras import utils as np_utils
import numpy as np
from keras import layers
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from keras.models import Model, load_model
from keras.preprocessing import image
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import preprocess_input
import pydot
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from keras.utils.vis_utils import plot_model
import keras.backend as k
from keras.initializers import glorot_uniform
import scipy.misc
from matplotlib.pyplot import imshow
from keras.utils.vis_utils import plot_model
from keras.initializers import glorot_uniform
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D

# %%
k.clear_session()
def inception_module(x, f1, f2, f3, f4, f5):
		# 1x1 conv
		conv1 = keras.layers.Conv2D(f1, (1,1), strides=(1, 1), padding='same', activation='relu')(x)
		# 3x3 conv
		conv3 = keras.layers.Conv2D(f2, (3,3), strides=(1, 1), padding='same', activation='relu')(x)
		# 5x5 conv
		conv5 = keras.layers.Conv2D(f3, (5,5), strides=(1, 1), padding='same', activation='relu')(x)
		conv7 = keras.layers.Conv2D(f4, (7,7), strides=(1, 1), padding='same', activation='relu')(x)
		conv9 = keras.layers.Conv2D(f5, (9,9), strides=(1, 1), padding='same', activation='relu')(x)
		x = keras.layers.merge.concatenate([conv1, conv3, conv5, conv7, conv9])
		return x

# %%
def conv2d_bn(x,filters,num_row,num_col,padding='same',strides=(1, 1)):
   
    x = keras.layers.Conv2D(filters, (num_row, num_col),strides=strides,padding=padding)(x)
    x = keras.layers.BatchNormalization(axis=3, scale=False)(x)
    x = keras.layers.Activation('relu')(x)
    return x

# %% [markdown]
# Model Build

# %%
img_input = keras.Input(shape=(224, 224, 3))  #shape=(None, 299, 299, 3)

# %%
#OURmODELv6
#conv2d_bn(x,filters,num_row,num_col,padding='same',strides=(1, 1))
x = conv2d_bn(img_input, 64, 7, 7, strides=(2, 2), padding='same') # 149 x 149 x 32
x = keras.layers.MaxPooling2D((2, 2), strides=(2, 2))(x)   # 73  x 73 x 64

x = conv2d_bn(x, 64, 1, 1, padding='same')  # 147 x 147 x 32
x = conv2d_bn(x, 192, 3, 3, padding='same') # 147 x 147 x 64
x = keras.layers.MaxPooling2D((2, 2), strides=(2, 2))(x)   # 73  x 73 x 64

#inception_module(x, f1, f2, f3)
x = inception_module(x, 128, 128, 128, 128, 128)
x = keras.layers.MaxPooling2D((2, 2), strides=(2, 2))(x)  # 35 x 35 x 512

x = inception_module(x, 192, 192, 192, 192, 192)
x = inception_module(x, 256, 256, 256, 256, 256)
x = inception_module(x, 256, 256, 256, 256, 256)
x = keras.layers.MaxPooling2D((2, 2), strides=(2, 2))(x)  # 35 x 35 x 512

x = inception_module(x, 512, 512, 512, 512, 512)
x = keras.layers.MaxPooling2D((7, 7), strides=(1, 1))(x)  # 35 x 35 x 192

#x = keras.layers.GlobalAveragePooling2D(name='avg_pool')(x) # shape=(None, 2048)
x = Flatten()(x)
x = keras.layers.Dense(1000, activation='relu')(x)
x = keras.layers.Dropout(0.5)(x)
x = keras.layers.Dense(2, activation='softmax', name='predictions')(x) #shape=(None, 1000)

# %%
# Create model.
inputs = img_input
model =  keras.Model(inputs, x, name='DFUEffectiveNetV4')
model.summary()


# plot model architecture
from tensorflow.keras.utils import plot_model
plot_model(model, show_shapes=True, to_file='DFUEffectiveNetV4.png')
# Out:
# Model: "DFUEffectiveNetV4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 112, 112, 64  9472        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 112, 112, 64  192        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 112, 112, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 56, 56, 64)   0           ['activation[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 56, 56, 64)   4160        ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 56, 56, 64)  192         ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 56, 56, 64)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 56, 56, 192)  110784      ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 56, 56, 192)  576        ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 56, 56, 192)  0           ['batch_normalization_2[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 28, 28, 192)  0          ['activation_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 28, 28, 128)  24704       ['max_pooling2d_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 28, 28, 128)  221312      ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 28, 28, 128)  614528      ['max_pooling2d_1[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 28, 28, 128)  1204352     ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 28, 28, 128)  1990784     ['max_pooling2d_1[0][0]']
#
#  concatenate (Concatenate)      (None, 28, 28, 640)  0           ['conv2d_3[0][0]',
#                                                                   'conv2d_4[0][0]',
#                                                                   'conv2d_5[0][0]',
#                                                                   'conv2d_6[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 14, 14, 640)  0          ['concatenate[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 14, 14, 192)  123072      ['max_pooling2d_2[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 14, 14, 192)  1106112     ['max_pooling2d_2[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 14, 14, 192)  3072192     ['max_pooling2d_2[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 14, 14, 192)  6021312     ['max_pooling2d_2[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 14, 14, 192)  9953472     ['max_pooling2d_2[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 14, 14, 960)  0           ['conv2d_8[0][0]',
#                                                                   'conv2d_9[0][0]',
#                                                                   'conv2d_10[0][0]',
#                                                                   'conv2d_11[0][0]',
#                                                                   'conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 14, 14, 256)  246016      ['concatenate_1[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 14, 14, 256)  2212096     ['concatenate_1[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 14, 14, 256)  6144256     ['concatenate_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 14, 14, 256)  12042496    ['concatenate_1[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 14, 14, 256)  19906816    ['concatenate_1[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 14, 14, 1280  0           ['conv2d_13[0][0]',
#                                 )                                 'conv2d_14[0][0]',
#                                                                   'conv2d_15[0][0]',
#                                                                   'conv2d_16[0][0]',
#                                                                   'conv2d_17[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 14, 14, 256)  327936      ['concatenate_2[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 14, 14, 256)  2949376     ['concatenate_2[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 14, 14, 256)  8192256     ['concatenate_2[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 14, 14, 256)  16056576    ['concatenate_2[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 14, 14, 256)  26542336    ['concatenate_2[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 14, 14, 1280  0           ['conv2d_18[0][0]',
#                                 )                                 'conv2d_19[0][0]',
#                                                                   'conv2d_20[0][0]',
#                                                                   'conv2d_21[0][0]',
#                                                                   'conv2d_22[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 7, 7, 1280)  0           ['concatenate_3[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 7, 7, 512)    655872      ['max_pooling2d_3[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 7, 7, 512)    5898752     ['max_pooling2d_3[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 7, 7, 512)    16384512    ['max_pooling2d_3[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 7, 7, 512)    32113152    ['max_pooling2d_3[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 7, 7, 512)    53084672    ['max_pooling2d_3[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 7, 7, 2560)   0           ['conv2d_23[0][0]',
#                                                                   'conv2d_24[0][0]',
#                                                                   'conv2d_25[0][0]',
#                                                                   'conv2d_26[0][0]',
#                                                                   'conv2d_27[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 1, 1, 2560)  0           ['concatenate_4[0][0]']
#
#  flatten (Flatten)              (None, 2560)         0           ['max_pooling2d_4[0][0]']
#
#  dense (Dense)                  (None, 1000)         2561000     ['flatten[0][0]']
#
#  dropout (Dropout)              (None, 1000)         0           ['dense[0][0]']
#
#  predictions (Dense)            (None, 2)            2002        ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 229,777,338
# Trainable params: 229,776,698
# Non-trainable params: 640
# __________________________________________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',optimizer = 'adam', metrics= 'accuracy')

# %%
tensorboard = TensorBoard(log_dir = 'logs')
checkpoint = ModelCheckpoint("AlexNet.h5",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.4, patience = 2, min_delta = 0.001,
                              mode='auto',verbose=1)

# %%
history = model.fit(X_train,y_train,validation_split=0.05, epochs =30, verbose=1, batch_size=32,
                   callbacks=[tensorboard,checkpoint,reduce_lr])
# Out:
# Epoch 1/30
# 86/86 [==============================] - ETA: 0s - loss: 655.7578 - accuracy: 0.7272
# Epoch 1: val_accuracy improved from -inf to 0.59722, saving model to AlexNet.h5
# 86/86 [==============================] - 148s 1s/step - loss: 655.7578 - accuracy: 0.7272 - val_loss: 0.9311 - val_accuracy: 0.5972 - lr: 0.0010
# Epoch 2/30
# 86/86 [==============================] - ETA: 0s - loss: 0.4272 - accuracy: 0.8122
# Epoch 2: val_accuracy improved from 0.59722 to 0.82639, saving model to AlexNet.h5
# 86/86 [==============================] - 90s 1s/step - loss: 0.4272 - accuracy: 0.8122 - val_loss: 0.5028 - val_accuracy: 0.8264 - lr: 0.0010
# Epoch 3/30
# 86/86 [==============================] - ETA: 0s - loss: 0.3473 - accuracy: 0.8625
# Epoch 3: val_accuracy improved from 0.82639 to 0.88194, saving model to AlexNet.h5
# 86/86 [==============================] - 91s 1s/step - loss: 0.3473 - accuracy: 0.8625 - val_loss: 0.2923 - val_accuracy: 0.8819 - lr: 0.0010
# Epoch 4/30
# 86/86 [==============================] - ETA: 0s - loss: 0.3175 - accuracy: 0.8731
# Epoch 4: val_accuracy improved from 0.88194 to 0.92361, saving model to AlexNet.h5
# 86/86 [==============================] - 91s 1s/step - loss: 0.3175 - accuracy: 0.8731 - val_loss: 0.2469 - val_accuracy: 0.9236 - lr: 0.0010
# Epoch 5/30
# 86/86 [==============================] - ETA: 0s - loss: 0.2968 - accuracy: 0.8845
# Epoch 5: val_accuracy did not improve from 0.92361
# 86/86 [==============================] - 78s 907ms/step - loss: 0.2968 - accuracy: 0.8845 - val_loss: 0.3000 - val_accuracy: 0.8750 - lr: 0.0010
# Epoch 6/30
# 86/86 [==============================] - ETA: 0s - loss: 0.3711 - accuracy: 0.8669
# Epoch 6: val_accuracy did not improve from 0.92361
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0004000000189989805.
# 86/86 [==============================] - 79s 921ms/step - loss: 0.3711 - accuracy: 0.8669 - val_loss: 0.2925 - val_accuracy: 0.8681 - lr: 0.0010
# Epoch 7/30
# 86/86 [==============================] - ETA: 0s - loss: 0.2497 - accuracy: 0.8959
# Epoch 7: val_accuracy did not improve from 0.92361
# 86/86 [==============================] - 79s 921ms/step - loss: 0.2497 - accuracy: 0.8959 - val_loss: 0.2426 - val_accuracy: 0.8889 - lr: 4.0000e-04
# Epoch 8/30
# 86/86 [==============================] - ETA: 0s - loss: 0.2256 - accuracy: 0.9127
# Epoch 8: val_accuracy did not improve from 0.92361
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.00016000000759959222.
# 86/86 [==============================] - 79s 923ms/step - loss: 0.2256 - accuracy: 0.9127 - val_loss: 0.2395 - val_accuracy: 0.8889 - lr: 4.0000e-04
# Epoch 9/30
# 86/86 [==============================] - ETA: 0s - loss: 0.2010 - accuracy: 0.9179
# Epoch 9: val_accuracy did not improve from 0.92361
# 86/86 [==============================] - 79s 922ms/step - loss: 0.2010 - accuracy: 0.9179 - val_loss: 0.2213 - val_accuracy: 0.9167 - lr: 1.6000e-04
# Epoch 10/30
# 86/86 [==============================] - ETA: 0s - loss: 0.1905 - accuracy: 0.9230
# Epoch 10: val_accuracy did not improve from 0.92361
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 6.40000042039901e-05.
# 86/86 [==============================] - 79s 922ms/step - loss: 0.1905 - accuracy: 0.9230 - val_loss: 0.2305 - val_accuracy: 0.9028 - lr: 1.6000e-04
# Epoch 11/30
# 86/86 [==============================] - ETA: 0s - loss: 0.1732 - accuracy: 0.9322
# Epoch 11: val_accuracy did not improve from 0.92361
# 86/86 [==============================] - 78s 908ms/step - loss: 0.1732 - accuracy: 0.9322 - val_loss: 0.2200 - val_accuracy: 0.9028 - lr: 6.4000e-05
# Epoch 12/30
# 86/86 [==============================] - ETA: 0s - loss: 0.1661 - accuracy: 0.9340
# Epoch 12: val_accuracy did not improve from 0.92361
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 2.560000284574926e-05.
# 86/86 [==============================] - 79s 922ms/step - loss: 0.1661 - accuracy: 0.9340 - val_loss: 0.2121 - val_accuracy: 0.9097 - lr: 6.4000e-05
# Epoch 13/30
# 86/86 [==============================] - ETA: 0s - loss: 0.1538 - accuracy: 0.9402
# Epoch 13: val_accuracy did not improve from 0.92361
# 86/86 [==============================] - 78s 909ms/step - loss: 0.1538 - accuracy: 0.9402 - val_loss: 0.2089 - val_accuracy: 0.9097 - lr: 2.5600e-05
# Epoch 14/30
# 86/86 [==============================] - ETA: 0s - loss: 0.1485 - accuracy: 0.9399
# Epoch 14: val_accuracy did not improve from 0.92361
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 1.0240000847261399e-05.
# 86/86 [==============================] - 79s 922ms/step - loss: 0.1485 - accuracy: 0.9399 - val_loss: 0.2104 - val_accuracy: 0.9167 - lr: 2.5600e-05
# Epoch 15/30
# 86/86 [==============================] - ETA: 0s - loss: 0.1485 - accuracy: 0.9406
# Epoch 15: val_accuracy did not improve from 0.92361
# 86/86 [==============================] - 79s 922ms/step - loss: 0.1485 - accuracy: 0.9406 - val_loss: 0.2084 - val_accuracy: 0.9236 - lr: 1.0240e-05
# Epoch 16/30
# 86/86 [==============================] - ETA: 0s - loss: 0.1465 - accuracy: 0.9384
# Epoch 16: val_accuracy did not improve from 0.92361
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 4.09600033890456e-06.
# 86/86 [==============================] - 79s 922ms/step - loss: 0.1465 - accuracy: 0.9384 - val_loss: 0.2070 - val_accuracy: 0.9167 - lr: 1.0240e-05
# Epoch 17/30
# 86/86 [==============================] - ETA: 0s - loss: 0.1532 - accuracy: 0.9369
# Epoch 17: val_accuracy did not improve from 0.92361
# 86/86 [==============================] - 79s 922ms/step - loss: 0.1532 - accuracy: 0.9369 - val_loss: 0.2082 - val_accuracy: 0.9167 - lr: 4.0960e-06
# Epoch 18/30
# 86/86 [==============================] - ETA: 0s - loss: 0.1439 - accuracy: 0.9443
# Epoch 18: val_accuracy did not improve from 0.92361
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1.6384001355618238e-06.
# 86/86 [==============================] - 79s 922ms/step - loss: 0.1439 - accuracy: 0.9443 - val_loss: 0.2081 - val_accuracy: 0.9167 - lr: 4.0960e-06
# Epoch 19/30
# 86/86 [==============================] - ETA: 0s - loss: 0.1427 - accuracy: 0.9421
# Epoch 19: val_accuracy did not improve from 0.92361
# 86/86 [==============================] - 79s 922ms/step - loss: 0.1427 - accuracy: 0.9421 - val_loss: 0.2076 - val_accuracy: 0.9236 - lr: 1.6384e-06
# Epoch 20/30
# 86/86 [==============================] - ETA: 0s - loss: 0.1431 - accuracy: 0.9391
# Epoch 20: val_accuracy did not improve from 0.92361
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 6.553600542247295e-07.
# 86/86 [==============================] - 79s 923ms/step - loss: 0.1431 - accuracy: 0.9391 - val_loss: 0.2079 - val_accuracy: 0.9236 - lr: 1.6384e-06
# Epoch 21/30
# 86/86 [==============================] - ETA: 0s - loss: 0.1402 - accuracy: 0.9435
# Epoch 21: val_accuracy did not improve from 0.92361
# 86/86 [==============================] - 78s 909ms/step - loss: 0.1402 - accuracy: 0.9435 - val_loss: 0.2078 - val_accuracy: 0.9236 - lr: 6.5536e-07
# Epoch 22/30
# 86/86 [==============================] - ETA: 0s - loss: 0.1452 - accuracy: 0.9424
# Epoch 22: val_accuracy did not improve from 0.92361
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 2.6214402168989184e-07.
# 86/86 [==============================] - 79s 921ms/step - loss: 0.1452 - accuracy: 0.9424 - val_loss: 0.2078 - val_accuracy: 0.9167 - lr: 6.5536e-07
# Epoch 23/30
# 86/86 [==============================] - ETA: 0s - loss: 0.1413 - accuracy: 0.9421
# Epoch 23: val_accuracy did not improve from 0.92361
# 86/86 [==============================] - 79s 922ms/step - loss: 0.1413 - accuracy: 0.9421 - val_loss: 0.2080 - val_accuracy: 0.9167 - lr: 2.6214e-07
# Epoch 24/30
# 86/86 [==============================] - ETA: 0s - loss: 0.1458 - accuracy: 0.9399
# Epoch 24: val_accuracy did not improve from 0.92361
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.0485761094969349e-07.
# 86/86 [==============================] - 79s 922ms/step - loss: 0.1458 - accuracy: 0.9399 - val_loss: 0.2080 - val_accuracy: 0.9167 - lr: 2.6214e-07
# Epoch 25/30
# 86/86 [==============================] - ETA: 0s - loss: 0.1470 - accuracy: 0.9417
# Epoch 25: val_accuracy did not improve from 0.92361
# 86/86 [==============================] - 79s 922ms/step - loss: 0.1470 - accuracy: 0.9417 - val_loss: 0.2079 - val_accuracy: 0.9236 - lr: 1.0486e-07
# Epoch 26/30
# 86/86 [==============================] - ETA: 0s - loss: 0.1406 - accuracy: 0.9428
# Epoch 26: val_accuracy did not improve from 0.92361
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 4.1943044948311586e-08.
# 86/86 [==============================] - 79s 922ms/step - loss: 0.1406 - accuracy: 0.9428 - val_loss: 0.2079 - val_accuracy: 0.9236 - lr: 1.0486e-07
# Epoch 27/30
# 86/86 [==============================] - ETA: 0s - loss: 0.1472 - accuracy: 0.9380
# Epoch 27: val_accuracy did not improve from 0.92361
# 86/86 [==============================] - 79s 922ms/step - loss: 0.1472 - accuracy: 0.9380 - val_loss: 0.2078 - val_accuracy: 0.9236 - lr: 4.1943e-08
# Epoch 28/30
# 86/86 [==============================] - ETA: 0s - loss: 0.1454 - accuracy: 0.9413
# Epoch 28: val_accuracy did not improve from 0.92361
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.677721854775882e-08.
# 86/86 [==============================] - 79s 921ms/step - loss: 0.1454 - accuracy: 0.9413 - val_loss: 0.2077 - val_accuracy: 0.9236 - lr: 4.1943e-08
# Epoch 29/30
# 86/86 [==============================] - ETA: 0s - loss: 0.1365 - accuracy: 0.9450
# Epoch 29: val_accuracy did not improve from 0.92361
# 86/86 [==============================] - 79s 921ms/step - loss: 0.1365 - accuracy: 0.9450 - val_loss: 0.2074 - val_accuracy: 0.9236 - lr: 1.6777e-08
# Epoch 30/30
# 86/86 [==============================] - ETA: 0s - loss: 0.1451 - accuracy: 0.9424
# Epoch 30: val_accuracy did not improve from 0.92361
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 6.710887134886434e-09.
# 86/86 [==============================] - 79s 922ms/step - loss: 0.1451 - accuracy: 0.9424 - val_loss: 0.2077 - val_accuracy: 0.9167 - lr: 1.6777e-08

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy',fontweight='bold')
plt.xlim([0,20])
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy',fontweight='bold', fontsize=14)
plt.xlabel('Epochs',fontweight='bold')
# plt.legend(loc='best')
plt.savefig('DFUEffectiveNetV4TV1',dpi=400)
plt.show()

# %%
filterwarnings('ignore')

epochs = [i for i in range(30)]
fig, ax = plt.subplots(1,2,figsize=(14,7))
train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']

fig.text(s='Epochs vs. Training and Validation Accuracy/Loss',size=14,fontweight='bold',
             fontname='monospace',color='#313131',y=1,x=0.28,alpha=0.8)

sns.despine()
ax[0].plot(epochs, train_acc, marker='o',markerfacecolor='#4F7942',color='#74C365',
           label = 'Training Accuracy')
ax[0].plot(epochs, val_acc, marker='o',markerfacecolor='#9E1717',color='#D35151',
           label = 'Validation Accuracy')
ax[0].legend(frameon=False)
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Training & Validation Accuracy')

sns.despine()
ax[1].plot(epochs, train_loss, marker='*',markerfacecolor='#4F7942',color='#74C365',
           label ='Training Loss')
ax[1].plot(epochs, val_loss, marker='*',markerfacecolor='#9E1717',color='#D35151',
           label = 'Validation Loss')
ax[1].legend(frameon=False)
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Training & Validation Loss')
plt.savefig('DFUEffectiveNetV4TV2',dpi=400)
fig.show()

# %%
pred = model.predict(X_test)
pred = np.argmax(pred,axis=1)
y_test_new = np.argmax(y_test,axis=1)

# %%
print(classification_report(y_test_new,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.89      0.92       195
#            1       0.84      0.92      0.88       124
#
#     accuracy                           0.90       319
#    macro avg       0.90      0.91      0.90       319
# weighted avg       0.91      0.90      0.90       319

# %%
cm = confusion_matrix(y_test_new, pred)

# %%
import itertools
from itertools import product
def plot_confusion_matrix(cm, classes,normalize=False,title='Confusion matrix',cmap=plt.cm.Blues):
    
    plt.figure(figsize=(7,5))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=40)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True/Actual label')
    plt.xlabel('Predicted label')

plot_confusion_matrix(cm,labels)
plt.savefig('ODFUEffectiveNetV4CM',dpi=400)
# Out:
# Confusion matrix, without normalization

# %%
TP=cm[1,1]
TN=cm[0,0]
FP=cm[0,1]
FN=cm[1,0]

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score,confusion_matrix, roc_curve, auc,roc_auc_score

print('Accuracy: %.3f' % accuracy_score(y_test_new, pred), 'Precision: %.3f' % precision_score(y_test_new, pred),' Recall: %.3f' % recall_score(y_test_new, pred), 
      'F1 Score: %.3f' % f1_score(y_test_new, pred), 'AUC Score: %.3f' % roc_auc_score(y_test_new, pred))
# Out:
# Accuracy: 0.903 Precision: 0.844  Recall: 0.919 F1 Score: 0.880 AUC Score: 0.906

# %%
recall=TP/float(TP+FN)
print(recall)
print(recall_score(y_test_new, pred))
# Out:
# 0.9193548387096774
# 0.9193548387096774

# %%
precision=TP/float(TP+FP)
print(precision)

print(precision_score(y_test_new, pred))
# Out:
# 0.8444444444444444
# 0.8444444444444444

# %%
print((2*precision*recall)/(recall+precision))
print(f1_score(y_test_new, pred))
# Out:
# 0.8803088803088802
# 0.8803088803088802

# %%
specificity=TN/float(TN+FP)
print(specificity)
# Out:
# 0.8923076923076924

# %%
print(TP/float(TP+FN))
print(recall_score(y_test_new, pred))
# Out:
# 0.9193548387096774
# 0.9193548387096774

# %%
print(roc_auc_score(y_test_new, pred))
# Out:
# 0.9058312655086849

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test_new, pred)
# Out:
# 0.09717868338557993

# %%
#Print Area Under Curve
false_positive_rate, recall, thresholds = roc_curve(y_test_new, pred)
roc_auc = auc(false_positive_rate, recall)
plt.figure()
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.plot(false_positive_rate, recall, 'b', label = 'AUC = %0.3f' %roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1], [0,1], 'r--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.0])
plt.ylabel('Recall')
plt.xlabel('Fall-out (1-Specificity)')
plt.show()

# %%
acc = accuracy_score(y_test_new, pred)*100
auc=roc_auc_score(y_test_new, pred)*100
tn, fp, fn, tp = cm.ravel()
precision = tp/(tp+fp)*100
recall = tp/(tp+fn)*100
specificity = tn/(tn+fp)*100
print('Accuracy: {0:0.2f}%'.format(acc))
print('Precision: {0:0.2f}%'.format(precision))
print('Recall or Sensitivity: {0:0.2f}%'.format(recall))
print('Specificity: {0:0.2f}%'.format(specificity))
print('F1-score: {0:0.2f}%'.format(2*precision*recall/(precision+recall)))
print('AUC-score: {0:0.2f}%'.format(auc))
print('Train acc: {0:0.2f}%'.format(np.round((history.history['accuracy'][-1])*100, 2)))
# Out:
# Accuracy: 90.28%
# Precision: 84.44%
# Recall or Sensitivity: 91.94%
# Specificity: 89.23%
# F1-score: 88.03%
# AUC-score: 90.58%
# Train acc: 94.24%

# %%
from tensorflow import argmax
from tensorflow import expand_dims
from matplotlib import pyplot as plt


#Take matplotlib frame and remove axes.
def clean_plot(plot):
    plot.axes.get_xaxis().set_visible(False)
    plot.axes.get_yaxis().set_visible(False)

#Dict mapping from class numbers to string labels:
class_names = {
        0: "Abnormal(Ulcer)",
        1: "Normal(Healthy skin)",
    }

#Loads a sample batch of data
sample_batch_input, sample_labels = test_iterator.next()
    
#Grabs the first five images
sample_batch_input = sample_batch_input[:5]
sample_labels = sample_labels[:5]

#Makes predictions using model.predict(x)
sample_predictions = model.predict(sample_batch_input)

#Iterate of images, predictions, and true labels
for i, (image, prediction, label) in enumerate(zip(sample_batch_input, sample_predictions, sample_labels)):

    image_name = "DFU {}".format(i)

    #Gets predicted class with highest probability
    predicted_class = argmax(prediction).numpy()

    #Gets correct label
    actual_class = argmax(label).numpy()

    print(image_name)
    print("\tModel prediction: {}".format(prediction))
    print("\tCategory: {} ({})".format(class_names[actual_class], actual_class))

    #Saves image file using matplotlib
    sample_image = image
    clean_plot(plt.imshow(
    sample_image[:, :, 0],
    cmap = "gray"
        ))
    plt.title("{}".format(class_names[predicted_class]))
    plt.tight_layout()
    plt.show()
    plt.clf()
